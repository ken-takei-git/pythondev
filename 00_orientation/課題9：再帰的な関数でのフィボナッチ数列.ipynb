# %%
import prognum # prognum.py

# 数値の入力、表示
num = int(input("何番目の数値を求めますか？："))
print("何番目の数値を求めますか？：", num)
# フィボナッチ数列関数
p_num = prognum.fibonacci(num)
# 答えの表示
print(p_num)
# Out:
# 何番目の数値を求めますか？： 10
# 55
