# %%
print("start")
num = ["Fizz Buzz" if (i % 3 == 0) and (i % 5 == 0) else "Fizz" if (i % 3 == 0) 
        else "Buzz" if (i % 5 == 0) else str(i) for i in range(1, 101)]
print(num)

"""
# 1から100まで繰り返す
for i in range(1, 101):
    # 3で割り切れてかつ5で割り切れる
    if (i % 3 == 0) and (i % 5 == 0):
        print("FizzBuzz")
    # 3で割り切れる
    elif (i % 3 == 0):
        print("Fizz")
    # 5で割り切れる
    elif (i % 5 == 0):
        print("Buzz")
    #それ以外
    else:
     print(i) #数値表示
"""
# Out:
# start
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 print("start")
# ----> 2 num = ["Fizz Buzz" if (i % 3 == 0) and (i % 5 == 0) else "Fizz" if (i % 3 == 0)
#       3         else "Buzz" if (i % 5 == 0) else char(i) for i in range(1, 101)]
#       4 print(num)
#       5
#
# NameError: name 'char' is not defined
